# %%
import pandas as pd
import numpy as np
import re
import plotly.express as px

# %%
# Load the main CSV
df = pd.read_csv("RozeePK-Jobs-2024.csv")
df.head()
# Out:
#                                      Title                      Salary  \
# 0                Order Fulfillment Manager  PKR. 30,000 - 60,000/Month
# 1  Enterprise Business Development Manager                         NaN
# 2                             Video Editor  PKR. 30,000 - 30,000/Month
# 3               Branch in Charge (Patokki)  PKR. 60,000 - 60,000/Month
# 4                     Senior PHP Developer                         NaN
#
#               Job Type                                       Job Location  \
# 0  Full Time/Permanent  Lahore,\n                                     ...
# 1  Full Time/Permanent  Lahore,\n                                     ...
# 2  Full Time/Permanent  Karachi,\n                                    ...
# 3  Full Time/Permanent  Patoki,\n                                     ...
# 4  Full Time/Permanent  Lahore,\n                                     ...
#
#   Functional Area              Career Level Apply Before Minimum Experience  \
# 0          Retail  Experienced Professional     3-Jan-25            2 Years
# 1             NaN                       NaN    19-Jan-25            3 Years
# 2             NaN                       NaN    19-Jan-25             1 Year
# 3             NaN                       NaN    19-Jan-25            3 Years
# 4             NaN                       NaN    19-Jan-25            3 Years
#
#       Minimum Education         Gender  Age  \
# 0  Intermediate/A-Level           Male  NaN
# 1                   NaN  No Preference  NaN
# 2                   NaN  No Preference  NaN
# 3                   NaN  No Preference  NaN
# 4                   NaN  No Preference  NaN
#
#                                               Skills
# 0  Team Building, Order Tracking, Order Processin...
# 1  Relationship Building, Sales Acumen, Market Re...
# 2                                       Video Editor
# 3  Customer Service, Problem Solving, Communicati...
# 4  PHP, MySQL, Javascript, Laravel, HTML, CSS, Gi...

# %% [markdown]
# # Cleaning Data to Prepare for Dash Board

# %%
df.columns = (
    df.columns
    .str.strip()
    .str.lower()
    .str.replace(" ", "_")
)

# %%
#Drop Irrelevant Columns
df = df.drop(columns=["apply_before", "age", "gender"])
df.head()
# Out:
#                                      title                      salary  \
# 0                Order Fulfillment Manager  PKR. 30,000 - 60,000/Month
# 1  Enterprise Business Development Manager                         NaN
# 2                             Video Editor  PKR. 30,000 - 30,000/Month
# 3               Branch in Charge (Patokki)  PKR. 60,000 - 60,000/Month
# 4                     Senior PHP Developer                         NaN
#
#               job_type                                       job_location  \
# 0  Full Time/Permanent  Lahore,\n                                     ...
# 1  Full Time/Permanent  Lahore,\n                                     ...
# 2  Full Time/Permanent  Karachi,\n                                    ...
# 3  Full Time/Permanent  Patoki,\n                                     ...
# 4  Full Time/Permanent  Lahore,\n                                     ...
#
#   functional_area              career_level minimum_experience  \
# 0          Retail  Experienced Professional            2 Years
# 1             NaN                       NaN            3 Years
# 2             NaN                       NaN             1 Year
# 3             NaN                       NaN            3 Years
# 4             NaN                       NaN            3 Years
#
#       minimum_education                                             skills
# 0  Intermediate/A-Level  Team Building, Order Tracking, Order Processin...
# 1                   NaN  Relationship Building, Sales Acumen, Market Re...
# 2                   NaN                                       Video Editor
# 3                   NaN  Customer Service, Problem Solving, Communicati...
# 4                   NaN  PHP, MySQL, Javascript, Laravel, HTML, CSS, Gi...

# %%
df.shape
# Out:
# (1059, 9)

# %% [markdown]
# ## Removing Null values

# %%
df.isna().sum()
# Out:
# title                  25
# salary                314
# job_type               25
# job_location           25
# functional_area       163
# career_level          163
# minimum_experience    312
# minimum_education     196
# skills                 26
# dtype: int64

# %%
#Removing Null values from "Title" & "Apply Before"
df = df.dropna(subset=["title", "job_location"])

# %%
# Null value in Functional Area ,Career Level  &  Skills 
df["functional_area"] = df["functional_area"].fillna("Other").str.title()
df["career_level"] = df["career_level"].fillna("Not Specified")
df["skills"] = df["skills"].fillna("Not Specified")

# %% [markdown]
# ## Cleaning salary column

# %%
# Cleaning salary column
def salary_to_mean(s):
    if pd.isna(s):
        return np.nan

    # Extract numbers
    nums = re.findall(r"\d[\d,]*", s)
    nums = [int(x.replace(",", "")) for x in nums]

    if len(nums) == 2:
        return np.mean(nums)
    elif len(nums) == 1:
        return nums[0]
    else:
        return np.nan

df["Salary"] = df["salary"].apply(salary_to_mean)

# Replace NaN with overall mean
df["Salary"] = df["Salary"].fillna(df["Salary"].mean())
df = df.drop(columns=["salary"])

# %% [markdown]
# ## Cleaning Job Type Column

# %%
# Cleaning Job Type Column
def clean_job_type(x):
    if pd.isna(x):
        return np.nan
    x = x.lower()
    if "full" in x:
        return "Full Time"
    if "part" in x:
        return "Part Time"
    return "Other"

df["Job Type"] = df["job_type"].apply(clean_job_type)

# Remove null job-type rows
df = df.dropna(subset=["Job Type"])
df = df.drop(columns=["job_type"])

# %% [markdown]
# ## Cleaning Job Location Column

# %%
# cleaning Job Location Column
valid_cities = [
    "Karachi","Lahore","Islamabad","Rawalpindi","Faisalabad","Peshawar",
    "Multan","Quetta","Hyderabad","Gujranwala","Sialkot","Bahawalpur",
    "Sargodha","Sukkur","Abbottabad","Mardan","Swat","Okara","Kasur",
    "Sheikhupura","Nawabshah","Mirpur","Gujrat","Rahim Yar Khan","Attock"
]

pattern = r"\b(" + "|".join(valid_cities) + r")\b"

def extract_city(text):
    if pd.isna(text):
        return np.nan
    m = re.search(pattern, text, flags=re.IGNORECASE)
    if m:
        return m.group(1)
    return "Other"

df["City"] = df["job_location"].apply(extract_city)
df = df.dropna(subset=["City"])
df = df.drop(columns=["job_location"])

# %% [markdown]
# ## Cleaning Experience Required Column

# %%
# cleaning Experience Required Column
df = df.copy()
def exp_to_num(x):
    if pd.isna(x):
        return np.nan
    m = re.search(r"(\d+)", str(x))
    return int(m.group(1)) if m else np.nan

df["Experience"] = df["minimum_experience"].apply(exp_to_num)
df["Experience"] = df["Experience"].fillna(df["Experience"].mean())
df = df.drop(columns=["minimum_experience"])

# %%
def exp_level(x):
    if x <= 1:
        return "Entry"
    elif x <= 3:
        return "Junior"
    elif x <= 5:
        return "Mid"
    else:
        return "Senior"

df["experience_level"] = df["Experience"].apply(exp_level)

# %% [markdown]
# ##  Cleaning Skills column

# %%
# Step 1: Clean skills
def clean_skills(skill_text):
    # If null
    if pd.isna(skill_text):
        return []
    
    # If it's already a list
    if isinstance(skill_text, list):
        skills = skill_text
    else:
        # Convert to string
        skill_text = str(skill_text).strip()
        if skill_text.lower() == "not specified" or skill_text == "":
            return []
        skills = skill_text.split(",")
    
    # Normalize: lowercase, strip spaces, remove empty strings
    skills = [s.strip().lower() for s in skills if s.strip() != ""]
    return skills

# %%
df.head()
# Out:
#                                      title functional_area  \
# 0                Order Fulfillment Manager          Retail
# 1  Enterprise Business Development Manager           Other
# 2                             Video Editor           Other
# 3               Branch in Charge (Patokki)           Other
# 4                     Senior PHP Developer           Other
#
#                career_level     minimum_education  \
# 0  Experienced Professional  Intermediate/A-Level
# 1             Not Specified                   NaN
# 2             Not Specified                   NaN
# 3             Not Specified                   NaN
# 4             Not Specified                   NaN
#
#                                               skills        Salary   Job Type  \
# 0  Team Building, Order Tracking, Order Processin...  45000.000000  Full Time
# 1  Relationship Building, Sales Acumen, Market Re...  82639.597315  Full Time
# 2                                       Video Editor  30000.000000  Full Time
# 3  Customer Service, Problem Solving, Communicati...  60000.000000  Full Time
# 4  PHP, MySQL, Javascript, Laravel, HTML, CSS, Gi...  82639.597315  Full Time
#
#       City  Experience experience_level
# 0   Lahore         2.0           Junior
# 1   Lahore         3.0           Junior
# 2  Karachi         1.0            Entry
# 3    Other         3.0           Junior
# 4   Lahore         3.0           Junior

# %% [markdown]
# # Making A new Dataset Having Clean Required column

# %%
df_clean = df[[
    "title",
    "City",
    "Salary",
    "Experience","experience_level",
    "Job Type","functional_area","career_level","skills"
]]
df_clean.head()
# Out:
#                                      title     City        Salary  Experience  \
# 0                Order Fulfillment Manager   Lahore  45000.000000         2.0
# 1  Enterprise Business Development Manager   Lahore  82639.597315         3.0
# 2                             Video Editor  Karachi  30000.000000         1.0
# 3               Branch in Charge (Patokki)    Other  60000.000000         3.0
# 4                     Senior PHP Developer   Lahore  82639.597315         3.0
#
#   experience_level   Job Type functional_area              career_level  \
# 0           Junior  Full Time          Retail  Experienced Professional
# 1           Junior  Full Time           Other             Not Specified
# 2            Entry  Full Time           Other             Not Specified
# 3           Junior  Full Time           Other             Not Specified
# 4           Junior  Full Time           Other             Not Specified
#
#                                               skills
# 0  Team Building, Order Tracking, Order Processin...
# 1  Relationship Building, Sales Acumen, Market Re...
# 2                                       Video Editor
# 3  Customer Service, Problem Solving, Communicati...
# 4  PHP, MySQL, Javascript, Laravel, HTML, CSS, Gi...

# %%
# Save df_clean to CSV
df_clean.to_csv("RozeePk-2024.csv", index=False)

# %%
# Out:
# 'ls' is not recognized as an internal or external command,
# operable program or batch file.
